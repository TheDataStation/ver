# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200

# %%
times = []
with open("times.log", "r") as f:
    lines = f.readlines()
    for line in lines:
        times.append(float(line))
sample_portions = ["0.25", "0.5", "0.75", "1.0"]

plt.bar(sample_portions, times, width = 0.4)
plt.xlabel("sample portion")
plt.ylabel("run time(s)")
# Out:
# Text(0, 0.5, 'run time(s)')

# %%
num_views = []
compatible = []
contained = []
complementary = []
contradictory = []

with open("results.log", "r") as f:
    lines = f.readlines()
    for line in lines:
        nums = line.strip().split()
        num_views.append(int(nums[0]))
        compatible.append(int(nums[1]))
        contained.append(int(nums[2]))
        complementary.append(int(nums[3]))
        contradictory.append(int(nums[4]))

x = np.arange(len(sample_portions))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width, num_views, width, label='num views')
rects2 = ax.bar(x - width, compatible, width, label='num compatible group')
rects3 = ax.bar(x, contained, width, label='num largest contained view')
rects4 = ax.bar(
    x + width, contradictory, width, label='num contradictions')
rects5 = ax.bar(x + 2*width, complementary, width, label='num complementary pairs')

# Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('run time(s)')
ax.set_xlabel('sample portion')
ax.set_xticks(x, sample_portions)
ax.legend()

ax.bar_label(rects1, padding=2)
ax.bar_label(rects2, padding=2)
ax.bar_label(rects3, padding=2)
ax.bar_label(rects4, padding=2)
ax.bar_label(rects5, padding=2)

# ax.set_yscale('log')

fig.tight_layout()

plt.show()

# %%
labels = [500, 1000, 2000]
time_500 = [2.932798147201538, 5.243244171142578, 1057.8104031085968, 1373.2922151088715]
time_1000 = [6.028142213821411, 9.870358228683472, 3641.072788000107, 6624.540374040604]
time_2000 = [11.925531148910522, 16.36414098739624, 21033.039329767227, None]

compatible = [2.932798147201538, 6.028142213821411, 11.925531148910522]
contained = [5.243244171142578, 9.870358228683472, 16.36414098739624]
contradictory = [1057.8104031085968, 3641.072788000107, 21033.039329767227]
complementary = [1373.2922151088715, 6624.540374040604, np.nan]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 3 * width/2, compatible, width, label='compatible')
rects2 = ax.bar(x - width/2, contained, width, label='contained')
rects3 = ax.bar(x + width/2, contradictory, width, label='contradictory')
rects4 = ax.bar(x + 3 * width/2, complementary, width, label='complementary')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('run time(s)')
ax.set_xlabel('num views')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=2)
ax.bar_label(rects2, padding=2)
ax.bar_label(rects3, padding=2)
ax.bar_label(rects4, padding=2)

ax.set_yscale('log')

fig.tight_layout()

plt.show()

# %%
# 5.163903713226318 6.556666851043701 747.5191786289215 758.6800448894501
# 10.142134428024292 12.335853338241577 1608.61456990242 1598.0279803276062

labels = [500, 1000]

compatible = [5.163903713226318, 10.142134428024292]
contained = [6.556666851043701, 12.335853338241577]
contradictory = [747.5191786289215, 1608.61456990242]
complementary = [758.6800448894501, 1598.0279803276062]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 3 * width/2, compatible, width, label='compatible')
rects2 = ax.bar(x - width/2, contained, width, label='contained')
rects3 = ax.bar(x + width/2, contradictory, width, label='contradictory')
rects4 = ax.bar(x + 3 * width/2, complementary, width, label='complementary')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('run time(s)')
ax.set_xlabel('num views')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=2)
ax.bar_label(rects2, padding=2)
ax.bar_label(rects3, padding=2)
ax.bar_label(rects4, padding=2)

ax.set_yscale('log')

fig.tight_layout()

plt.show()
